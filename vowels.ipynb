# %%
def count_vowels(text: str) -> int:
    """
    args:
        Take a string as input
    Returns:
        returns total count of vowels in the string
    """
    if not isinstance(text, str):
        raise TypeError("Input string hona chahiye")

    text = text.lower().strip()
    vowels = "aeiou"
    count = 0
    for char in text:
        if char in vowels:
            count += 1
    return count
def main():
    try:
        user_input = input("Enter a string: ")
        if user_input.strip() == "":
            raise ValueError("Empty string allowed nahi hai")
        result = count_vowels(user_input)
        print("Total vowels in string:", result)

    except (TypeError, ValueError) as e:
        print("Error:", e)
    except Exception as e:
        print("Unexpected Error:", e)
if __name__ == "__main__":
    main()
# Out:
# Enter a string:  pankaj yadav
# Total vowels in string: 4
